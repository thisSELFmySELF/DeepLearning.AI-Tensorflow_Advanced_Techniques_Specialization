# %% [markdown]
# # Simple Object Detection in Tensorflow
#
# This lab will walk you through how to use object detection models available in [Tensorflow Hub](https://www.tensorflow.org/hub). In the following sections, you will:
#
# * explore the Tensorflow Hub for object detection models
# * load the models in your workspace
# * preprocess an image for inference
# * run inference on the models and inspect the output
#
# Let's get started!

# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
import tensorflow_hub as hub
from PIL import Image
from PIL import ImageOps
import tempfile
from six.moves.urllib.request import urlopen
from six import BytesIO
# Out:
# 2023-07-15 13:26:23.654268: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Download the model from Tensorflow Hub
#
# Tensorflow Hub is a repository of trained machine learning models which you can reuse in your own projects.
# - You can see the domains covered [here](https://tfhub.dev/) and its subcategories.
# - For this lab, you will want to look at the [image object detection subcategory](https://tfhub.dev/s?module-type=image-object-detection).
# - You can select a model to see more information about it and copy the URL so you can download it to your workspace.
# - We selected a [inception resnet version 2](https://tfhub.dev/google/faster_rcnn/openimages_v4/inception_resnet_v2/1)
# - You can also modify this following cell to choose the other model that we selected, [ssd mobilenet version 2](https://tfhub.dev/tensorflow/ssd_mobilenet_v2/2)

# %%
# you can switch the commented lines here to pick the other model

# inception resnet version 2
module_handle = "https://tfhub.dev/google/faster_rcnn/openimages_v4/inception_resnet_v2/1"

# You can choose ssd mobilenet version 2 instead and compare the results
#module_handle = "https://tfhub.dev/google/openimages_v4/ssd/mobilenet_v2/1"

# %% [markdown]
# #### Load the model
#
# Next, you'll load the model specified by the `module_handle`.
# - This will take a few minutes to load the model.

# %%
model = hub.load(module_handle)
# Out:
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# 2023-07-15 13:27:15.365456: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_36' with dtype int32
# 	 [[{{node unused_control_flow_input_36}}]]
# 2023-07-15 13:27:15.413482: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_48' with dtype int32
# 	 [[{{node unused_control_flow_input_48}}]]
# 2023-07-15 13:27:15.460006: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_60' with dtype int32
# 	 [[{{node unused_control_flow_input_60}}]]
# 2023-07-15 13:27:15.481198: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_65' with dtype int32
# 	 [[{{node unused_control_flow_input_65}}]]
# 2023-07-15 13:27:15.531398: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_77' with dtype int32
# 	 [[{{node unused_control_flow_input_77}}]]
# 2023-07-15 13:27:15.580138: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_89' with dtype int32
# 	 [[{{node unused_control_flow_input_89}}]]
# 2023-07-15 13:27:15.634221: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_101' with dtype int32
# 	 [[{{node unused_control_flow_input_101}}]]
# 2023-07-15 13:27:15.680074: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_113' with dtype int32
# 	 [[{{node unused_control_flow_input_113}}]]
# 2023-07-15 13:27:15.726973: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_125' with dtype int32
# 	 [[{{node unused_control_flow_input_125}}]]
# 2023-07-15 13:27:15.779147: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_137' with dtype int32
# 	 [[{{node unused_control_flow_input_137}}]]
# 2023-07-15 13:27:15.833409: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_149' with dtype int32
# 	 [[{{node unused_control_flow_input_149}}]]
# 2023-07-15 13:27:15.880869: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_161' with dtype int32
# 	 [[{{node unused_control_flow_input_161}}]]
# 2023-07-15 13:27:15.924828: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_173' with dtype int32
# 	 [[{{node unused_control_flow_input_173}}]]
# 2023-07-15 13:27:15.970351: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_185' with dtype int32
# 	 [[{{node unused_control_flow_input_185}}]]
# 2023-07-15 13:27:15.983107: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_190' with dtype int32
# 	 [[{{node unused_control_flow_input_190}}]]
# 2023-07-15 13:27:16.028898: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_202' with dtype int32
# 	 [[{{node unused_control_flow_input_202}}]]
# 2023-07-15 13:27:16.079764: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_214' with dtype int32
# 	 [[{{node unused_control_flow_input_214}}]]
# 2023-07-15 13:27:16.125835: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_226' with dtype int32
# 	 [[{{node unused_control_flow_input_226}}]]
# 2023-07-15 13:27:16.171546: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_238' with dtype int32
# 	 [[{{node unused_control_flow_input_238}}]]
# 2023-07-15 13:27:16.216262: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_250' with dtype int32
# 	 [[{{node unused_control_flow_input_250}}]]
# 2023-07-15 13:27:16.260782: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_262' with dtype int32
# 	 [[{{node unused_control_flow_input_262}}]]
# 2023-07-15 13:27:16.311225: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_274' with dtype int32
# 	 [[{{node unused_control_flow_input_274}}]]
# 2023-07-15 13:27:16.360807: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_286' with dtype int32
# 	 [[{{node unused_control_flow_input_286}}]]
# 2023-07-15 13:27:16.410945: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_298' with dtype int32
# 	 [[{{node unused_control_flow_input_298}}]]
# 2023-07-15 13:27:16.458503: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_310' with dtype int32
# 	 [[{{node unused_control_flow_input_310}}]]
# 2023-07-15 13:27:16.507206: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_322' with dtype int32
# 	 [[{{node unused_control_flow_input_322}}]]
# 2023-07-15 13:27:16.560615: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_334' with dtype int32
# 	 [[{{node unused_control_flow_input_334}}]]
# 2023-07-15 13:27:16.609869: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_346' with dtype int32
# 	 [[{{node unused_control_flow_input_346}}]]
# 2023-07-15 13:27:16.659160: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_358' with dtype int32
# 	 [[{{node unused_control_flow_input_358}}]]
# 2023-07-15 13:27:16.673261: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_363' with dtype int32
# 	 [[{{node unused_control_flow_input_363}}]]
# 2023-07-15 13:27:16.720257: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_375' with dtype int32
# 	 [[{{node unused_control_flow_input_375}}]]
# 2023-07-15 13:27:16.766502: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_387' with dtype int32
# 	 [[{{node unused_control_flow_input_387}}]]
# 2023-07-15 13:27:16.819102: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_399' with dtype int32
# 	 [[{{node unused_control_flow_input_399}}]]
# 2023-07-15 13:27:16.870205: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_411' with dtype int32
# 	 [[{{node unused_control_flow_input_411}}]]
# 2023-07-15 13:27:16.916151: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_423' with dtype int32
# 	 [[{{node unused_control_flow_input_423}}]]
# 2023-07-15 13:27:16.962276: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_435' with dtype int32
# 	 [[{{node unused_control_flow_input_435}}]]
# 2023-07-15 13:27:17.007986: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_447' with dtype int32
# 	 [[{{node unused_control_flow_input_447}}]]
# 2023-07-15 13:27:17.055701: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_459' with dtype int32
# 	 [[{{node unused_control_flow_input_459}}]]
# 2023-07-15 13:27:17.103004: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_471' with dtype int32
# 	 [[{{node unused_control_flow_input_471}}]]
# 2023-07-15 13:27:17.117244: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_476' with dtype int32
# 	 [[{{node unused_control_flow_input_476}}]]
# 2023-07-15 13:27:17.130225: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_481' with dtype int32
# 	 [[{{node unused_control_flow_input_481}}]]
# 2023-07-15 13:27:17.177305: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_493' with dtype int32
# 	 [[{{node unused_control_flow_input_493}}]]
# 2023-07-15 13:27:17.228986: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_507' with dtype int32
# 	 [[{{node unused_control_flow_input_507}}]]
# 2023-07-15 13:27:17.277973: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_519' with dtype int32
# 	 [[{{node unused_control_flow_input_519}}]]
# 2023-07-15 13:27:17.326955: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_531' with dtype int32
# 	 [[{{node unused_control_flow_input_531}}]]
# 2023-07-15 13:27:17.376171: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_543' with dtype int32
# 	 [[{{node unused_control_flow_input_543}}]]
# 2023-07-15 13:27:17.423877: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_555' with dtype int32
# 	 [[{{node unused_control_flow_input_555}}]]
# 2023-07-15 13:27:17.470904: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_567' with dtype int32
# 	 [[{{node unused_control_flow_input_567}}]]
# 2023-07-15 13:27:17.484102: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_572' with dtype int32
# 	 [[{{node unused_control_flow_input_572}}]]
# 2023-07-15 13:27:17.537556: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_584' with dtype int32
# 	 [[{{node unused_control_flow_input_584}}]]
# 2023-07-15 13:27:17.553461: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_589' with dtype int32
# 	 [[{{node unused_control_flow_input_589}}]]
# 2023-07-15 13:27:17.605471: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_601' with dtype int32
# 	 [[{{node unused_control_flow_input_601}}]]
# 2023-07-15 13:27:17.656877: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_613' with dtype int32
# 	 [[{{node unused_control_flow_input_613}}]]
# 2023-07-15 13:27:17.705230: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_625' with dtype int32
# 	 [[{{node unused_control_flow_input_625}}]]
# 2023-07-15 13:27:17.717882: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_630' with dtype int32
# 	 [[{{node unused_control_flow_input_630}}]]
# 2023-07-15 13:27:17.769900: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_642' with dtype int32
# 	 [[{{node unused_control_flow_input_642}}]]
# 2023-07-15 13:27:17.819579: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_654' with dtype int32
# 	 [[{{node unused_control_flow_input_654}}]]
# 2023-07-15 13:27:17.842714: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_660' with dtype int32
# 	 [[{{node unused_control_flow_input_660}}]]
# 2023-07-15 13:27:17.888396: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_672' with dtype int32
# 	 [[{{node unused_control_flow_input_672}}]]
# 2023-07-15 13:27:17.935340: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_684' with dtype int32
# 	 [[{{node unused_control_flow_input_684}}]]
# 2023-07-15 13:27:17.957415: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_689' with dtype int32
# 	 [[{{node unused_control_flow_input_689}}]]
# 2023-07-15 13:27:18.009228: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_701' with dtype int32
# 	 [[{{node unused_control_flow_input_701}}]]
# 2023-07-15 13:27:18.061244: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_713' with dtype int32
# 	 [[{{node unused_control_flow_input_713}}]]
# 2023-07-15 13:27:18.115711: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_725' with dtype int32
# 	 [[{{node unused_control_flow_input_725}}]]
# 2023-07-15 13:27:18.178924: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_737' with dtype int32
# 	 [[{{node unused_control_flow_input_737}}]]
# 2023-07-15 13:27:18.244056: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_749' with dtype int32
# 	 [[{{node unused_control_flow_input_749}}]]
# 2023-07-15 13:27:18.302834: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_761' with dtype int32
# 	 [[{{node unused_control_flow_input_761}}]]
# 2023-07-15 13:27:18.357910: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_773' with dtype int32
# 	 [[{{node unused_control_flow_input_773}}]]
# 2023-07-15 13:27:18.430591: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_785' with dtype int32
# 	 [[{{node unused_control_flow_input_785}}]]
# 2023-07-15 13:27:18.520296: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_797' with dtype int32
# 	 [[{{node unused_control_flow_input_797}}]]
# 2023-07-15 13:27:18.582530: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_809' with dtype int32
# 	 [[{{node unused_control_flow_input_809}}]]
# 2023-07-15 13:27:18.641614: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_821' with dtype int32
# 	 [[{{node unused_control_flow_input_821}}]]
# 2023-07-15 13:27:18.699741: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_833' with dtype int32
# 	 [[{{node unused_control_flow_input_833}}]]
# 2023-07-15 13:27:18.760004: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_845' with dtype int32
# 	 [[{{node unused_control_flow_input_845}}]]
# 2023-07-15 13:27:18.826377: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_857' with dtype int32
# 	 [[{{node unused_control_flow_input_857}}]]
# 2023-07-15 13:27:18.885643: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_869' with dtype int32
# 	 [[{{node unused_control_flow_input_869}}]]
# 2023-07-15 13:27:18.940481: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_881' with dtype int32
# 	 [[{{node unused_control_flow_input_881}}]]
# 2023-07-15 13:27:19.009925: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_893' with dtype int32
# 	 [[{{node unused_control_flow_input_893}}]]
# 2023-07-15 13:27:19.081213: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_905' with dtype int32
# 	 [[{{node unused_control_flow_input_905}}]]
# 2023-07-15 13:27:19.139882: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_917' with dtype int32
# 	 [[{{node unused_control_flow_input_917}}]]
# 2023-07-15 13:27:19.156436: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_922' with dtype int32
# 	 [[{{node unused_control_flow_input_922}}]]
# 2023-07-15 13:27:19.215495: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_934' with dtype int32
# 	 [[{{node unused_control_flow_input_934}}]]
# 2023-07-15 13:27:19.281415: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_948' with dtype int32
# 	 [[{{node unused_control_flow_input_948}}]]
# 2023-07-15 13:27:19.340432: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_960' with dtype int32
# 	 [[{{node unused_control_flow_input_960}}]]
# 2023-07-15 13:27:19.397325: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_972' with dtype int32
# 	 [[{{node unused_control_flow_input_972}}]]
# 2023-07-15 13:27:19.466450: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_984' with dtype int32
# 	 [[{{node unused_control_flow_input_984}}]]
# 2023-07-15 13:27:19.541562: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_996' with dtype int32
# 	 [[{{node unused_control_flow_input_996}}]]
# 2023-07-15 13:27:19.606410: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1008' with dtype int32
# 	 [[{{node unused_control_flow_input_1008}}]]
# 2023-07-15 13:27:19.662030: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1020' with dtype int32
# 	 [[{{node unused_control_flow_input_1020}}]]
# 2023-07-15 13:27:19.721505: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1032' with dtype int32
# 	 [[{{node unused_control_flow_input_1032}}]]
# 2023-07-15 13:27:19.783840: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1044' with dtype int32
# 	 [[{{node unused_control_flow_input_1044}}]]
# 2023-07-15 13:27:20.055586: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1056' with dtype int32
# 	 [[{{node unused_control_flow_input_1056}}]]
# 2023-07-15 13:27:20.118624: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1068' with dtype int32
# 	 [[{{node unused_control_flow_input_1068}}]]
# 2023-07-15 13:27:20.177476: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1080' with dtype int32
# 	 [[{{node unused_control_flow_input_1080}}]]
# 2023-07-15 13:27:20.235003: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1092' with dtype int32
# 	 [[{{node unused_control_flow_input_1092}}]]
# 2023-07-15 13:27:20.298684: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1104' with dtype int32
# 	 [[{{node unused_control_flow_input_1104}}]]
# 2023-07-15 13:27:20.360470: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1116' with dtype int32
# 	 [[{{node unused_control_flow_input_1116}}]]
# 2023-07-15 13:27:20.422856: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1128' with dtype int32
# 	 [[{{node unused_control_flow_input_1128}}]]
# 2023-07-15 13:27:20.478735: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1140' with dtype int32
# 	 [[{{node unused_control_flow_input_1140}}]]
# 2023-07-15 13:27:20.540987: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1152' with dtype int32
# 	 [[{{node unused_control_flow_input_1152}}]]
# 2023-07-15 13:27:20.609650: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1164' with dtype int32
# 	 [[{{node unused_control_flow_input_1164}}]]
# 2023-07-15 13:27:20.675751: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1176' with dtype int32
# 	 [[{{node unused_control_flow_input_1176}}]]
# 2023-07-15 13:27:20.736230: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1188' with dtype int32
# 	 [[{{node unused_control_flow_input_1188}}]]
# 2023-07-15 13:27:20.798946: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1200' with dtype int32
# 	 [[{{node unused_control_flow_input_1200}}]]
# 2023-07-15 13:27:20.859148: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1212' with dtype int32
# 	 [[{{node unused_control_flow_input_1212}}]]
# 2023-07-15 13:27:20.917877: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1224' with dtype int32
# 	 [[{{node unused_control_flow_input_1224}}]]
# 2023-07-15 13:27:20.974695: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1236' with dtype int32
# 	 [[{{node unused_control_flow_input_1236}}]]
# 2023-07-15 13:27:21.035250: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1248' with dtype int32
# 	 [[{{node unused_control_flow_input_1248}}]]
# 2023-07-15 13:27:21.054250: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1253' with dtype int32
# 	 [[{{node unused_control_flow_input_1253}}]]
# 2023-07-15 13:27:21.110811: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1265' with dtype int32
# 	 [[{{node unused_control_flow_input_1265}}]]
# 2023-07-15 13:27:21.161874: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1277' with dtype int32
# 	 [[{{node unused_control_flow_input_1277}}]]
# 2023-07-15 13:27:21.210675: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1289' with dtype int32
# 	 [[{{node unused_control_flow_input_1289}}]]
# 2023-07-15 13:27:21.266034: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1303' with dtype int32
# 	 [[{{node unused_control_flow_input_1303}}]]
# 2023-07-15 13:27:21.314864: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1315' with dtype int32
# 	 [[{{node unused_control_flow_input_1315}}]]
# 2023-07-15 13:27:21.370124: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1327' with dtype int32
# 	 [[{{node unused_control_flow_input_1327}}]]
# 2023-07-15 13:27:21.423724: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1339' with dtype int32
# 	 [[{{node unused_control_flow_input_1339}}]]
# 2023-07-15 13:27:21.473303: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1351' with dtype int32
# 	 [[{{node unused_control_flow_input_1351}}]]
# 2023-07-15 13:27:21.525434: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1363' with dtype int32
# 	 [[{{node unused_control_flow_input_1363}}]]
# 2023-07-15 13:27:21.575338: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1377' with dtype int32
# 	 [[{{node unused_control_flow_input_1377}}]]
# 2023-07-15 13:27:21.622599: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1389' with dtype int32
# 	 [[{{node unused_control_flow_input_1389}}]]
# 2023-07-15 13:27:21.671317: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1401' with dtype int32
# 	 [[{{node unused_control_flow_input_1401}}]]
# 2023-07-15 13:27:21.737110: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1413' with dtype int32
# 	 [[{{node unused_control_flow_input_1413}}]]
# 2023-07-15 13:27:21.789831: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1425' with dtype int32
# 	 [[{{node unused_control_flow_input_1425}}]]
# 2023-07-15 13:27:21.847722: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1437' with dtype int32
# 	 [[{{node unused_control_flow_input_1437}}]]
# 2023-07-15 13:27:21.903598: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1449' with dtype int32
# 	 [[{{node unused_control_flow_input_1449}}]]
# 2023-07-15 13:27:21.962670: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1461' with dtype int32
# 	 [[{{node unused_control_flow_input_1461}}]]
# 2023-07-15 13:27:22.024293: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1473' with dtype int32
# 	 [[{{node unused_control_flow_input_1473}}]]
# 2023-07-15 13:27:22.084057: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1485' with dtype int32
# 	 [[{{node unused_control_flow_input_1485}}]]
# 2023-07-15 13:27:22.148677: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1497' with dtype int32
# 	 [[{{node unused_control_flow_input_1497}}]]
# 2023-07-15 13:27:22.214389: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1509' with dtype int32
# 	 [[{{node unused_control_flow_input_1509}}]]
# 2023-07-15 13:27:22.278184: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1521' with dtype int32
# 	 [[{{node unused_control_flow_input_1521}}]]
# 2023-07-15 13:27:22.337590: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1533' with dtype int32
# 	 [[{{node unused_control_flow_input_1533}}]]
# 2023-07-15 13:27:22.396578: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1545' with dtype int32
# 	 [[{{node unused_control_flow_input_1545}}]]
# 2023-07-15 13:27:22.458962: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_1557' with dtype int32
# 	 [[{{node unused_control_flow_input_1557}}]]
# ...
# 	 [[{{node unused_control_flow_input_6849}}]]
# 2023-07-15 13:27:42.799317: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_6882' with dtype int32
# 	 [[{{node unused_control_flow_input_6882}}]]
# 2023-07-15 13:27:42.859357: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_6894' with dtype int32
# 	 [[{{node unused_control_flow_input_6894}}]]
# 2023-07-15 13:27:42.950814: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_6917' with dtype int32
# 	 [[{{node unused_control_flow_input_6917}}]]
# 2023-07-15 13:27:43.127514: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_6931' with dtype int32
# 	 [[{{node unused_control_flow_input_6931}}]]
# 2023-07-15 13:27:43.136329: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_6934' with dtype int32
# 	 [[{{node unused_control_flow_input_6934}}]]
# 2023-07-15 13:27:43.144501: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_6937' with dtype int32
# 	 [[{{node unused_control_flow_input_6937}}]]
# 2023-07-15 13:27:43.149260: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_6939' with dtype int32
# 	 [[{{node unused_control_flow_input_6939}}]]
# 2023-07-15 13:27:43.170032: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_6943' with dtype int32
# 	 [[{{node unused_control_flow_input_6943}}]]
# 2023-07-15 13:27:43.190622: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_6947' with dtype int32
# 	 [[{{node unused_control_flow_input_6947}}]]
# 2023-07-15 13:27:43.216538: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_6953' with dtype int32
# 	 [[{{node unused_control_flow_input_6953}}]]
# 2023-07-15 13:27:43.261434: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_6963' with dtype int32
# 	 [[{{node unused_control_flow_input_6963}}]]
# 2023-07-15 13:27:43.288465: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_6969' with dtype int32
# 	 [[{{node unused_control_flow_input_6969}}]]
# 2023-07-15 13:27:48.760868: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_6981' with dtype int32
# 	 [[{{node unused_control_flow_input_6981}}]]
# 2023-07-15 13:27:48.819062: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_6993' with dtype int32
# 	 [[{{node unused_control_flow_input_6993}}]]
# 2023-07-15 13:27:48.924837: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_7005' with dtype int32
# 	 [[{{node unused_control_flow_input_7005}}]]
# 2023-07-15 13:27:48.977946: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_7017' with dtype int32
# 	 [[{{node unused_control_flow_input_7017}}]]
# 2023-07-15 13:27:49.047274: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_7029' with dtype int32
# 	 [[{{node unused_control_flow_input_7029}}]]
# 2023-07-15 13:27:49.107546: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_7041' with dtype int32
# 	 [[{{node unused_control_flow_input_7041}}]]
# 2023-07-15 13:27:49.173051: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_7053' with dtype int32
# 	 [[{{node unused_control_flow_input_7053}}]]
# 2023-07-15 13:27:49.239800: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_7065' with dtype int32
# 	 [[{{node unused_control_flow_input_7065}}]]
# 2023-07-15 13:27:49.302943: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_7078' with dtype int32
# 	 [[{{node unused_control_flow_input_7078}}]]
# 2023-07-15 13:27:49.357080: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_7090' with dtype int32
# 	 [[{{node unused_control_flow_input_7090}}]]
# 2023-07-15 13:27:49.428827: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_7102' with dtype int32
# 	 [[{{node unused_control_flow_input_7102}}]]
# 2023-07-15 13:27:49.496479: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_7112' with dtype int32
# 	 [[{{node unused_control_flow_input_7112}}]]
# 2023-07-15 13:27:49.511483: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_7116' with dtype int32
# 	 [[{{node unused_control_flow_input_7116}}]]
# 2023-07-15 13:27:49.575815: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_7128' with dtype int32
# 	 [[{{node unused_control_flow_input_7128}}]]
# 2023-07-15 13:27:49.640597: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_7141' with dtype int32
# 	 [[{{node unused_control_flow_input_7141}}]]
# 2023-07-15 13:27:49.707281: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_7153' with dtype int32
# 	 [[{{node unused_control_flow_input_7153}}]]
# 2023-07-15 13:27:49.769371: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_7165' with dtype int32
# 	 [[{{node unused_control_flow_input_7165}}]]
# 2023-07-15 13:27:49.831074: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_7177' with dtype int32
# 	 [[{{node unused_control_flow_input_7177}}]]
# 2023-07-15 13:27:49.888255: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_7187' with dtype int32
# 	 [[{{node unused_control_flow_input_7187}}]]
# 2023-07-15 13:27:49.894034: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_7189' with dtype int32
# 	 [[{{node unused_control_flow_input_7189}}]]
# 2023-07-15 13:27:49.918702: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_7193' with dtype int32
# 	 [[{{node unused_control_flow_input_7193}}]]
# 2023-07-15 13:27:49.955139: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_7199' with dtype int32
# 	 [[{{node unused_control_flow_input_7199}}]]
# 2023-07-15 13:27:50.017417: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_7211' with dtype int32
# 	 [[{{node unused_control_flow_input_7211}}]]
# 2023-07-15 13:27:50.069091: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_7221' with dtype int32
# 	 [[{{node unused_control_flow_input_7221}}]]
# 2023-07-15 13:27:50.096664: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_7227' with dtype int32
# 	 [[{{node unused_control_flow_input_7227}}]]
# 2023-07-15 13:27:50.159835: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_7239' with dtype int32
# 	 [[{{node unused_control_flow_input_7239}}]]
# 2023-07-15 13:27:50.221393: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_7251' with dtype int32
# 	 [[{{node unused_control_flow_input_7251}}]]
# 2023-07-15 13:27:50.286677: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_7263' with dtype int32
# 	 [[{{node unused_control_flow_input_7263}}]]
# 2023-07-15 13:27:50.350094: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_7274' with dtype int32
# 	 [[{{node unused_control_flow_input_7274}}]]
# 2023-07-15 13:27:50.420943: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_7281' with dtype int32
# 	 [[{{node unused_control_flow_input_7281}}]]
# 2023-07-15 13:27:50.481665: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_7293' with dtype int32
# 	 [[{{node unused_control_flow_input_7293}}]]
# 2023-07-15 13:27:50.499458: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'unused_control_flow_input_7298' with dtype int32
# 	 [[{{node unused_control_flow_input_7298}}]]

# %% [markdown]
# #### Choose the default signature
#
# Some models in the Tensorflow hub can be used for different tasks. So each model's documentation should show what *signature* to use when running the model.
# - If you want to see if a model has more than one signature then you can do something like `print(hub.load(module_handle).signatures.keys())`. In your case, the models you will be using only have the `default` signature so you don't have to worry about other types.

# %%
# take a look at the available signatures for this particular model
model.signatures.keys()
# Out:
# KeysView(_SignatureMap({'default': <ConcreteFunction pruned(images) at 0x7FE10C207F40>}))

# %% [markdown]
# Please choose the 'default' signature for your object detector.
# - For object detection models, its 'default' signature will accept a batch of image tensors and output a dictionary describing the objects detected, which is what you'll want here.

# %%
detector = model.signatures['default']

# %% [markdown]
# ### download_and_resize_image
#
# This function downloads an image specified by a given "url", pre-processes it, and then saves it to disk.

# %%
def download_and_resize_image(url, new_width=256, new_height=256):
    '''
    Fetches an image online, resizes it and saves it locally.
    
    Args:
        url (string) -- link to the image
        new_width (int) -- size in pixels used for resizing the width of the image
        new_height (int) -- size in pixels used for resizing the length of the image
        
    Returns:
        (string) -- path to the saved image
    '''
    
    # create a temporary file ending with ".jpg"
    _, filename = tempfile.mkstemp(suffix=".jpg")
    
    # opens the given URL
    response = urlopen(url)
    
    # reads the image fetched from the URL
    image_data = response.read()
    
    # puts the image data in memory buffer
    image_data = BytesIO(image_data)
    
    # opens the image
    pil_image = Image.open(image_data)
    
    # resizes the image. will crop if aspect ratio is different.
    pil_image = ImageOps.fit(pil_image, (new_width, new_height), Image.ANTIALIAS)
    
    # converts to the RGB colorspace
    pil_image_rgb = pil_image.convert("RGB")
    
    # saves the image to the temporary file created earlier
    pil_image_rgb.save(filename, format="JPEG", quality=90)
    
    print("Image downloaded to %s." % filename)
    
    return filename

# %% [markdown]
# ### Download and preprocess an image
#
# Now, using `download_and_resize_image` you can get a sample image online and save it locally.
# - We've provided a URL for you, but feel free to choose another image to run through the object detector.
# - You can use the original width and height of the image but feel free to modify it and see what results you get.

# %%
# You can choose a different URL that points to an image of your choice
image_url = "https://upload.wikimedia.org/wikipedia/commons/f/fb/20130807_dublin014.JPG"

# download the image and use the original height and width
downloaded_image_path = download_and_resize_image(image_url, 3872, 2592)
# Out:
# /var/folders/0h/674kd08n4x31w0wzlnb63lr40000gn/T/ipykernel_4362/26980486.py:30: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   pil_image = ImageOps.fit(pil_image, (new_width, new_height), Image.ANTIALIAS)
# Image downloaded to /var/folders/0h/674kd08n4x31w0wzlnb63lr40000gn/T/tmp345y2p1_.jpg.

# %% [markdown]
# ### run_detector
#
# This function will take in the object detection model `detector` and the path to a sample image, then use this model to detect objects and display its predicted class categories and detection boxes.
# - run_detector uses `load_image` to convert the image into a tensor.

# %%
def load_img(path):
    '''
    Loads a JPEG image and converts it to a tensor.
    
    Args:
        path (string) -- path to a locally saved JPEG image
    
    Returns:
        (tensor) -- an image tensor
    '''
    
    # read the file
    img = tf.io.read_file(path)
    
    # convert to a tensor
    img = tf.image.decode_jpeg(img, channels=3)
    
    return img


def run_detector(detector, path):
    '''
    Runs inference on a local file using an object detection model.
    
    Args:
        detector (model) -- an object detection model loaded from TF Hub
        path (string) -- path to an image saved locally
    '''
    
    # load an image tensor from a local file path
    img = load_img(path)

    # add a batch dimension in front of the tensor
    converted_img  = tf.image.convert_image_dtype(img, tf.float32)[tf.newaxis, ...]
    
    # run inference using the model
    result = detector(converted_img)

    # save the results in a dictionary
    result = {key:value.numpy() for key,value in result.items()}

    # print results
    print("Found %d objects." % len(result["detection_scores"]))

    print(result["detection_scores"])
    print(result["detection_class_entities"])
    print(result["detection_boxes"])

# %% [markdown]
# ### Run inference on the image
#
# You can run your detector by calling the `run_detector` function. This will print the number of objects found followed by three lists:
#
# * The detection scores of each object found (i.e. how confident the model is),
# * The classes of each object found,
# * The bounding boxes of each object
#
# You will see how to overlay this information on the original image in the next sections and in this week's assignment!

# %%
# runs the object detection model and prints information about the objects found
run_detector(detector, downloaded_image_path)
# Out:
# 2023-07-15 13:29:00.315271: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -2484 } dim { size: -2485 } dim { size: -2486 } dim { size: 1088 } } } inputs { dtype: DT_FLOAT shape { dim { size: -105 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -105 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 17 } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 1200 num_cores: 8 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 49152 l2_cache_size: 524288 l3_cache_size: 8388608 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { dim { size: -105 } dim { size: 17 } dim { size: 17 } dim { size: 1088 } } }
# Found 100 objects.
# [0.65321785 0.6105043  0.6015254  0.59255713 0.59177667 0.58154947
#  0.5505313  0.495756   0.47424918 0.47322115 0.44066426 0.4051138
#  0.3980369  0.39406508 0.37148488 0.36155966 0.36150712 0.3468914
#  0.33362302 0.31252825 0.28878015 0.25758228 0.25748876 0.25196126
#  0.24782118 0.23412377 0.20431958 0.20324676 0.17988236 0.1796485
#  0.17374504 0.1643146  0.16031149 0.15895227 0.15620339 0.1546879
#  0.14754456 0.13622633 0.12740108 0.12555654 0.12102669 0.11813041
#  0.11387312 0.1122914  0.11129177 0.09718717 0.09137247 0.0897603
#  0.08880255 0.0863359  0.08337472 0.08095195 0.07988766 0.07741458
#  0.07732139 0.07631046 0.0750785  0.07386058 0.07233308 0.07204127
#  0.07110187 0.06935604 0.06825582 0.06427873 0.06248553 0.06226381
#  0.06211139 0.05940064 0.05798766 0.05784446 0.05725569 0.05346705
#  0.05304345 0.05242897 0.04892582 0.0481304  0.04578449 0.04424171
#  0.04337561 0.04277821 0.0426265  0.04163554 0.04081782 0.03976018
#  0.03945975 0.03944281 0.03863983 0.03769058 0.03759601 0.03566736
#  0.03359365 0.0333325  0.0327588  0.03231574 0.03134315 0.02978734
#  0.02858364 0.02856131 0.02822328 0.0278788 ]
# [b'Person' b'Person' b'Person' b'Person' b'Footwear' b'Person' b'Building'
#  b'Bicycle' b'Window' b'Building' b'Person' b'Wheel' b'Building'
#  b'Building' b'Person' b'Wheel' b'Building' b'Window' b'Window'
#  b'Building' b'Person' b'Van' b'Person' b'Bicycle wheel' b'Person'
#  b'Window' b'Window' b'Bicycle' b'Building' b'Window' b'Window' b'Man'
